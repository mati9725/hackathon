# %% [markdown]
# # BMMW
# ---

# %% [markdown]
# # Sprawdzanie dokładności modelu
# Plik test_data.csv jest dostępny tylko dla jury. Zawiera dane testowe - jednakowe dla wszystkich drużyn. Jest w takim samym formacie co zbiór, który otrzymaliście wraz z zadaniem, tylko już z czystymi danymi.

# %%
import pandas as pd
import numpy as np

# %%
test_data = pd.read_csv("test_data.csv")

# %% [markdown]
# ### Miejsce na twój kod:

# %%
import pickle

# %%
# Load settings file
settings = pickle.load(open("model.pkl", "rb"))

# remove automatically generated column (if exist)
if "Unnamed: 0" in test_data.columns:
    test_data = test_data.drop(columns = ["Unnamed: 0"])

# %%
data = test_data.drop(columns = ["Activity"])

# Normalization
x = data.values
columns = data.columns
print(columns)

data = settings["scaler"].transform(x)

# Features selection
data[:, settings["features"]]

# Encode activities
test_data = test_data.replace({"Activity" : settings["encoder"]})

# Make predictions
predicted = settings["model"].predict(data)
# Out:
# Index(['angle(X,gravityMean)', 'angle(Y,gravityMean)', 'angle(Z,gravityMean)',
#        'angle(tBodyAccJerkMean),gravityMean)', 'angle(tBodyAccMean,gravity)',
#        'angle(tBodyGyroJerkMean,gravityMean)',
#        'angle(tBodyGyroMean,gravityMean)', 'energy-mean()',
#        'fBodyAcc-bandsEnergy()-1,16', 'fBodyAcc-bandsEnergy()-1,16.1',
#        ...
#        'tGravityAccMag-energy()', 'tGravityAccMag-entropy()',
#        'tGravityAccMag-iqr()', 'tGravityAccMag-mad()', 'tGravityAccMag-max()',
#        'tGravityAccMag-mean()', 'tGravityAccMag-min()', 'tGravityAccMag-sma()',
#        'tGravityAccMag-std()', 'void()'],
#       dtype='object', length=571)

# %% [markdown]
# ### Sprawdzanie dokładności:
# Predicted - zmienna przechowująca przewidzianą aktywność. Poniższa linijka powinna zwrócić wartość 0-1.

# %%
print(list(predicted))
print(test_data.Activity)
# Out:
# [2, 5, 0, 3, 1, 0, 2, 4, 3, 2, 1, 0, 2, 1, 4, 2, 0, 0, 0, 4, 5, 0, 3, 2, 0, 0, 1, 0, 3, 4, 3, 5, 5, 0, 3, 4, 2, 4, 3, 0, 4, 4, 1, 0, 1, 4, 1, 0, 2, 0, 3, 3, 1, 0, 0, 4, 4, 5, 3, 4, 5, 3, 2, 5, 0, 1, 4, 1, 1, 2, 1, 0, 5, 5, 0, 5, 1, 4, 2, 1, 5, 4, 0, 4, 5, 5, 0, 2, 0, 1, 4, 2, 1, 2, 3, 5, 1, 1, 0, 3, 0, 4, 0, 3, 2, 3, 4, 3, 3, 2, 1, 1, 1, 1, 3, 1, 0, 5, 5, 1, 0, 2, 5, 1, 0, 1, 0, 5, 0, 0, 2, 3, 0, 0, 1, 3, 0, 4, 2, 2, 4, 2, 1, 4, 3, 0, 3, 1, 4, 5, 0, 5, 5, 0, 0, 3, 1, 5, 2, 2, 4, 2, 4, 1, 5, 0, 1, 0, 0, 3, 1, 3, 0, 4, 1, 5, 4, 3, 3, 4, 3, 0, 0, 2, 5, 4, 4, 1, 3, 3, 4, 1, 5, 0, 2, 3, 3, 2, 2, 4, 4, 2, 4, 3, 1, 3, 5, 2, 4, 0, 1, 3, 3, 3, 5, 5, 5, 1, 4, 1, 0, 1, 4, 4, 0, 2, 2, 5, 3, 1, 1, 1, 1, 2, 1, 1, 0, 3, 0, 1, 4, 3, 5, 3, 3, 4, 2, 2, 1, 3, 3, 1, 3, 3, 5, 4, 5, 0, 5, 4, 2, 2